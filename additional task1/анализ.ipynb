# %% [markdown]
# ### 📊Исследовательский анализ научных статей
#
# #### Введение
#
# Исследовательский анализ научных статей включает в себя детальное изучение различных аспектов публикаций, таких как:
#
# • Языки, на которых они написаны,
#
# • Тематики статей,
#
# • Проблемы, которые они поднимают.
#
# Это позволяет лучше понять текущее состояние науки, выявить актуальные проблемы и направления исследований.
#
# #### 🗾Языки статей
#
# • **Английский язык**: Большинство научных статей публикуются на английском языке, так как он является международным языком науки. Это обеспечивает широкий охват и доступность информации для ученых и исследователей по всему миру.
#
#
# • **Русский язык**: Несмотря на то, что русский язык также используется в научных публикациях, его доля значительно меньше по сравнению с английским. Это связано с тем, что русский язык менее распространен в международном научном сообществе.
#
# #### Тематика статей
#
# **🍏Естественные науки:**
#
# • **Физика**: Исследования в области физических явлений, законов и принципов.
#
# • **Химия**: Изучение химических реакций, соединений и свойств веществ.
#
# • **Биология**: Исследования живых организмов, их структуры, функций и процессов.
#
# **💾Технические науки:**
#
# • **Информатика**: Исследования в области информационных технологий, программного обеспечения и алгоритмов.
#
# • **Инженерия**: Разработка и проектирование инженерных систем и устройств.
#
# • **Технологии**: Применение новых технологий в различных областях, таких как медицина, промышленность и транспорт.
#
# #### ❕❗️Проблемы, поднимаемые в статьях
#
# **Медицинские проблемы:**
#
# • **Анализ болезней**: Сравнение различных заболеваний, выявление их различий и особенностей поведения.
#
# • **Анализ терапий**: Изучение влияния различных методов лечения на ткани и организм в целом.
#
# • **Сравнение наблюдений за пациентами**: Анализ данных, полученных в ходе наблюдений за пациентами, для выявления закономерностей и тенденций.
#
# **Технологические проблемы:**
#
# • **Искусственный интеллект**: Исследования в области разработки и применения искусственного интеллекта в различных сферах, включая медицину.
#
# • **Новые материалы**: Изучение свойств и возможностей новых материалов, их применение в различных отраслях.
#
# • **Польза искусственного интеллекта и машинного обучения в медицине**: Анализ эффективности и перспектив использования этих технологий в медицинской практике.

# %% [markdown]
# ### 📏 Метрики качества машинного перевода: BLEU и ROUGE
#
# BLEU (Bilingual Evaluation Understudy) и ROUGE (Recall-Oriented Understudy for Gisting Evaluation) — это популярные метрики оценки качества машинного перевода, которые также применимы к оценке качества сгенерированного текста в научных статьях.
#
# **BLEU (Bilingual Evaluation Understudy):**
#
# • **Преимущества:**
#
#
#   * **Простота в реализации**: BLEU легко рассчитать и интерпретировать.
#
#   * **Учитывает n-граммы**: BLEU учитывает n-граммы (последовательности слов) различной длины, что позволяет оценить, насколько хорошо модель захватила грамматику и стиль исходного текста.
#
#   * **Широкое распространение**: BLEU широко используется в исследованиях машинного перевода и генерации текста, что обеспечивает сравнительный анализ результатов.
#
# • **Недостатки:**
#
#
#   * **Не чувствительна к смыслу**: BLEU не может отличить синонимические варианты и не учитывает семантическую точность перевода.
#
#   * **Не учитывает порядок слов**: BLEU не чувствителен к порядку слов в предложении, что может привести к неверной оценке, если порядок слов важен для смысла.
#
#   * **Не учитывает релевантность**: BLEU не может оценить, насколько сгенерированный текст соответствует теме или релевантен исходному тексту.
#
#
# **ROUGE (Recall-Oriented Understudy for Gisting Evaluation):**
#
# • **Преимущества:**
#
#
#   * **Учитывает релевантность**: ROUGE фокусируется на схожести между сгенерированным текстом и референтным текстом, оценивая релевантность сгенерированного текста исходному тексту.
#
#   * **Учитывает ключевые слова**: ROUGE учитывает количество совпадений ключевых слов и фраз в сгенерированном тексте.
# • **Недостатки:**
#
#
#   * **Не учитывает грамматику и стиль**: ROUGE не чувствителен к грамматике и стилю сгенерированного текста, что может привести к неверной оценке в случаях, когда грамотность и стиль являются важными критериями.
#
#   * **Зависит от референтного текста**: ROUGE может быть неточным, если референтный текст не является идеальным или не отражает всех нюансов исходного текста.
#
# **Применение к научным статьям:**
#
# В контексте научных статей использование BLEU и ROUGE имеет свои особенности:
#
# • **BLEU**: BLEU может быть полезен для оценки грамматики и стиля сгенерированных абзацев или разделов статьи.
#
# • **ROUGE**: ROUGE может быть более полезен для оценки релевантности сгенерированного текста исходному тексту, например, для оценки качества краткого изложения научной статьи.
#
# **Вывод:**
# Для анализа сжатия текста, эти метрики являются наиболее объективными, поэтому мы будем отталкиваться от них при выборе языковой модели

# %% [markdown]
# ### 🎨 Ландшафт генеративных языковых моделей: Yandex, Gigachat и Chat
#
# Современный ландшафт генеративных языковых моделей изобилует разнообразием инструментов, каждый из которых обладает уникальным набором характеристик, определяющим его пригодность для различных задач. Рассматривая три модели - Yandex, Gigachat и Chat - мы обнаруживаем отчетливые различия в их подходе к генерации текста, что позволяет сделать вывод об их специализации и целевой аудитории.
#
# **Yandex** 💬 демонстрирует краткость и лаконичность, подобно концентрированному экстракту. Он предлагает краткое изложение ключевых аспектов темы, исключая все лишнее и фокусируясь на самом существенном. Такой подход отлично подходит для быстрого получения основной информации без погружения в детали.
#
# **Gigachat**, в свою очередь, представляет собой более развернутый и детализированный ответ. Он добавляет несколько дополнительных фактов и уточнений, что делает его ответ более полным и информативным, но не перегружает пользователя избытком информации.
#
# **Chat** 📝 же использует структурированный подход, подобный научному докладу. Он разбивает ответ на четко определенные пункты с заголовками и подпунктами, что обеспечивает ясность изложения и удобство восприятия. Кроме того, Chat предлагает краткий вывод, что позволяет сфокусировать внимание на ключевых моментах и усилить понимание информации.
#
# Таким образом, каждая из рассмотренных моделей обладает своими преимуществами и недостатками, и выбор наиболее подходящей модели зависит от конкретной задачи и требований пользователя.
#
# **Yandex** - отличный инструмент для быстрого получения ключевой информации.
# **Gigachat** предлагает более полный ответ с дополнительными деталями.
# **Chat** обеспечивает структурированный подход с четким выводом, что делает его идеальным инструментом для глубокого изучения темы.
#
#
# Использование Chat оказалось невозможным из-за региональных ограничений 🚫, что затруднило выполнение поставленных задач. В то время возникли сложности с созданием API для сайта с помощью сервисов Яндекса. 🛠️ Поэтому мы решили обратиться к GigaChat, который также успешно справился с задачей. 👍
